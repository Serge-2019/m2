# %% [markdown]
# # Тема “Введение в математических анализ”
#
# ### 1. Как относятся друг к другу множество и последовательность?
# (в ответе использовать слова типа: часть, целое, общее, частное, родитель, дочерний субъект и т.д.)

# %% [markdown]
# >  Последовательность — это результат последовательного выбора элементов из определенного множества, т.е. для каждого натурального числа можно указать элемент данного множества
#
# > Таким образом можно считать что последовательность может является частью множества

# %% [markdown]
# ### 2. Прочитать высказывания математической логики, построить их отрицания и установить истинность.

# %% [markdown]
# * https://github.com/Serge-2019/m2/blob/lesson2/lesson2/res11.jpg
# * https://github.com/Serge-2019/m2/blob/lesson2/lesson2/res12.jpg

# %% [markdown]
# # Тема “Множество”
#
# ### 1. Даны три множества a,b и с. Необходимо выполнить все изученные виды бинарных операций над всеми комбинациями множеств.
#
# * https://github.com/Serge-2019/m2/blob/lesson2/lesson2/res2.jpg

# %% [markdown]
# ### 2. *Выполнить задание 1 на языке Python

# %%
a = {1,2,3,4,5}
b = {2,4,6,8,10}
c = {3,6,9,12,15}

U = a | b | c # обозначим универсум

# пересечение
print(f'Пересечение a b: {a.intersection(b)}')
print(f'Пересечение c b: {c & b}') # другой способ

# обьеденение
print(f'Объеденение b c: {b.union(c)}')
print(f'Пересечение a & c | Объеденение b: {a & c | b}') # другой способ

# разность
print(f'Разность b - c: {b.difference(c)}')
print(f'Разность c - a - b: {c - a - b}') # другой способ

# Симметрическая разность
print(f'Симметрическая разность a - b: {a.symmetric_difference(b)}')
print(f'Симметрическая разность b - c: {b ^ c}') # другой способ

# Декартово произведение
from itertools import product, combinations
print(f'Декартово произведение a x b: {set(product(a,b))}')


# Дополнение
print(f'Дополнение b: {U - b}')

# Булеан
print(f'Булеан для a: {[set(combinations(a, i)) for i in range(0, len(a)+1)]}')
# Out:
# Пересечение a b: {2, 4}
# Пересечение c b: {6}
# Объеденение b c: {2, 3, 4, 6, 8, 9, 10, 12, 15}
# Пересечение a & c | Объеденение b: {2, 3, 4, 6, 8, 10}
# Разность b - c: {8, 2, 10, 4}
# Разность c - a - b: {9, 12, 15}
# Симметрическая разность a - b: {1, 3, 5, 6, 8, 10}
# Симметрическая разность b - c: {2, 3, 4, 8, 9, 10, 12, 15}
# Декартово произведение a x b: {(4, 8), (5, 6), (2, 8), (1, 6), (5, 8), (1, 2), (3, 10), (4, 4), (3, 6), (2, 2), (1, 10), (4, 10), (3, 2), (2, 6), (5, 4), (5, 2), (1, 4), (2, 10), (4, 2), (5, 10), (4, 6), (3, 8), (1, 8), (3, 4), (2, 4)}
# Дополнение b: {1, 3, 5, 9, 12, 15}
# Булеан для a: [{()}, {(1,), (2,), (3,), (4,), (5,)}, {(1, 2), (1, 3), (4, 5), (1, 4), (1, 5), (2, 3), (2, 5), (3, 4), (2, 4), (3, 5)}, {(2, 3, 5), (1, 2, 3), (1, 3, 5), (1, 4, 5), (1, 2, 4), (1, 3, 4), (2, 4, 5), (3, 4, 5), (2, 3, 4), (1, 2, 5)}, {(1, 2, 3, 4), (1, 3, 4, 5), (2, 3, 4, 5), (1, 2, 3, 5), (1, 2, 4, 5)}, {(1, 2, 3, 4, 5)}]

# %% [markdown]
# # Тема 3 “Последовательность”
#
# ### 1. Даны 4 последовательности.
#
# * https://github.com/Serge-2019/m2/blob/lesson2/lesson2/res31.jpg
# * https://github.com/Serge-2019/m2/blob/lesson2/lesson2/res32.jpg

# %%
from math import sqrt
def a(n):
    return 2**n - n

def b(n):
    if n==1:
        return 0
    return 1/(1-n)

def c(n):
    return (-1)**n + sqrt(2*n)

def d(n):
    return (-1)**(2*n) + 1/(n**2)
    
for i in range(1,5):
    print(f'{a(i):20} {b(i):20} {c(i):20} {d(i):20}')
# Out:
#                    1                    0  0.41421356237309515                  2.0
#                    2                 -1.0                  3.0                 1.25
#                    5                 -0.5   1.4494897427831779   1.1111111111111112
#                   12  -0.3333333333333333   3.8284271247461903               1.0625

# %% [markdown]
# ### 2. Найти 12-й член заданной неявно последовательности
#
# * https://github.com/Serge-2019/m2/blob/lesson2/lesson2/res4.jpg

# %% [markdown]
# ### 3. *На языке Python предложить алгоритм вычисляющий численно предел с точностью

# %%
from math import factorial

def f(n):
    return n / pow(factorial(n),1/n)

for n in range(1,100):
    prev = f(n-1) if n>1 else 0
    cur = f(n)
    print(f'{n:>4} = {cur:<20} | {cur-prev:<10}')
# Out:
#    1 = 1.0                  | 1.0
#    2 = 1.414213562373095    | 0.4142135623730949
#    3 = 1.6509636244473134   | 0.23675006207421845
#    4 = 1.8072040072196898   | 0.1562403827723764
#    5 = 1.9192597481868872   | 0.11205574096719739
#    6 = 2.0041451295984074   | 0.08488538141152024
#    7 = 2.070996628837124    | 0.0668514992387168
#    8 = 2.1252005594420327   | 0.05420393060490847
#    9 = 2.170156536901524    | 0.044955977459491425
#   10 = 2.2081252132060087   | 0.03796867630448464
#   11 = 2.2406732477028206   | 0.03254803449681187
#   12 = 2.268923390819235    | 0.028250143116414606
#   13 = 2.2937029551771286   | 0.024779564357893413
#   14 = 2.3156360189017344   | 0.021933063724605795
#   15 = 2.335202883868812    | 0.019566864967077713
#   16 = 2.352779665665871    | 0.017576781797058683
#   17 = 2.368665391348515    | 0.015885725682644125
#   18 = 2.3831009973869577   | 0.014435606038442739
#   19 = 2.396282932872044    | 0.013181935485086171
#   20 = 2.408373083650825    | 0.012090150778781172
#   21 = 2.419506134182143    | 0.011133050531317856
#   22 = 2.429795111070674    | 0.010288976888531032
#   23 = 2.4393356142427107   | 0.009540503172036807
#   24 = 2.448209086349558    | 0.008873472106847302
#   25 = 2.4564853674650906   | 0.00827628111553258
#   26 = 2.46422471189274     | 0.007739344427649453
#   27 = 2.471479395415468    | 0.007254683522727845
#   28 = 2.478295007345771    | 0.0068156119303028895
#   29 = 2.484711497582766    | 0.006416490236995198
#   30 = 2.4907640314928114   | 0.0060525339100454545
#   31 = 2.496483692754992    | 0.0057196612621805976
#   32 = 2.501898064970579    | 0.005414372215586827
#   33 = 2.5070317158777042   | 0.005133650907125364
#   34 = 2.511906602779828    | 0.004874886902123787
#   35 = 2.5165424138253716   | 0.004635811045543559
#   36 = 2.5209568567362743   | 0.0044144429109027605
#   37 = 2.525165904237891    | 0.0042090475016167694
#   38 = 2.5291840036193896   | 0.004018099381498441
#   39 = 2.533024256426202    | 0.0038402528068126607
